# %%
import pandas as pd 
import numpy as np
import seaborn as sn
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\tebik\OneDrive\Desktop\DataPy\Datasets\loan-test.csv')
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
#Handlemissing values
#===> Handling missing numercial values
#===> handlinf missing catagorical values

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# Loan_Status          29
# dtype: int64

# %%
#missed numerical values asre:
#===>Dependents 
#===> LoanAmount
#===> Loan_Amount_Term

# %%
#  The Dependents column contains non-numeric data, specifically strings like "3+. before fill the missing values Replace non-numeric values (like "3+") with a numeric equivalent or a placeholder.
## Convert '3+' to a numeric value 
df['Dependents'] = df['Dependents'].replace({'3+': 3})
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes          3  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df['Dependents'] = pd.to_numeric(df['Dependents'], errors='coerce')
df['Dependents'].fillna(df['Dependents'].mean(), inplace=True)
print("Updated 'Dependents' column:")
print(df['Dependents'])
# Out:
# Updated 'Dependents' column:
# 0      0.0
# 1      1.0
# 2      2.0
# 3      2.0
# 4      0.0
#       ...
# 362    3.0
# 363    0.0
# 364    0.0
# 365    0.0
# 366    0.0
# Name: Dependents, Length: 367, dtype: float64
# C:\Users\tebik\AppData\Local\Temp\ipykernel_29404\244961225.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Dependents'].fillna(df['Dependents'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            0
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# Loan_Status          29
# dtype: int64

# %%
#now Dependents column is clean and ready for further analysis.

# %%
# let handl next missing numerical values asre: 
#===> LoanAmount

# %%
# Fill missing values in 'LoanAmount' with the column mean
#df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)
#print(df['LoanAmount'])
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes         0.0      Graduate            No
# 1    LP001022   Male     Yes         1.0      Graduate            No
# 2    LP001031   Male     Yes         2.0      Graduate            No
# 3    LP001035   Male     Yes         2.0      Graduate            No
# 4    LP001051   Male      No         0.0  Not Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 362  LP002971   Male     Yes         3.0  Not Graduate           Yes
# 363  LP002975   Male     Yes         0.0      Graduate            No
# 364  LP002980   Male      No         0.0      Graduate            No
# 365  LP002986   Male     Yes         0.0      Graduate            No
# 366  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#let verify the column updated correctly
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            0
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# Loan_Status          29
# dtype: int64

# %%
df.head(50)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001015    Male     Yes    0.000000      Graduate            No
# 1   LP001022    Male     Yes    1.000000      Graduate            No
# 2   LP001031    Male     Yes    2.000000      Graduate            No
# 3   LP001035    Male     Yes    2.000000      Graduate            No
# 4   LP001051    Male      No    0.000000  Not Graduate            No
# 5   LP001054    Male     Yes    0.000000  Not Graduate           Yes
# 6   LP001055  Female      No    1.000000  Not Graduate            No
# 7   LP001056    Male     Yes    2.000000  Not Graduate            No
# 8   LP001059    Male     Yes    2.000000      Graduate           NaN
# 9   LP001067    Male      No    0.000000  Not Graduate            No
# 10  LP001078    Male      No    0.000000  Not Graduate            No
# 11  LP001082    Male     Yes    1.000000      Graduate           NaN
# 12  LP001083    Male      No    3.000000      Graduate            No
# ...

# %%
# Fill missing values in 'LoanAmount' with the column mean
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
print(df)
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes         0.0      Graduate            No
# 1    LP001022   Male     Yes         1.0      Graduate            No
# 2    LP001031   Male     Yes         2.0      Graduate            No
# 3    LP001035   Male     Yes         2.0      Graduate            No
# 4    LP001051   Male      No         0.0  Not Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 362  LP002971   Male     Yes         3.0  Not Graduate           Yes
# 363  LP002975   Male     Yes         0.0      Graduate            No
# 364  LP002980   Male      No         0.0      Graduate            No
# 365  LP002986   Male     Yes         0.0      Graduate            No
# 366  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Fill missing values in 'Loan_Amount_Term ' with the column mean
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
print(df)
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes         0.0      Graduate            No
# 1    LP001022   Male     Yes         1.0      Graduate            No
# 2    LP001031   Male     Yes         2.0      Graduate            No
# 3    LP001035   Male     Yes         2.0      Graduate            No
# 4    LP001051   Male      No         0.0  Not Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 362  LP002971   Male     Yes         3.0  Not Graduate           Yes
# 363  LP002975   Male     Yes         0.0      Graduate            No
# 364  LP002980   Male      No         0.0      Graduate            No
# 365  LP002986   Male     Yes         0.0      Graduate            No
# 366  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            0
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       29
# Property_Area         0
# Loan_Status          29
# dtype: int64

# %%
df.head(50)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001015    Male     Yes    0.000000      Graduate            No
# 1   LP001022    Male     Yes    1.000000      Graduate            No
# 2   LP001031    Male     Yes    2.000000      Graduate            No
# 3   LP001035    Male     Yes    2.000000      Graduate            No
# 4   LP001051    Male      No    0.000000  Not Graduate            No
# 5   LP001054    Male     Yes    0.000000  Not Graduate           Yes
# 6   LP001055  Female      No    1.000000  Not Graduate            No
# 7   LP001056    Male     Yes    2.000000  Not Graduate            No
# 8   LP001059    Male     Yes    2.000000      Graduate           NaN
# 9   LP001067    Male      No    0.000000  Not Graduate            No
# 10  LP001078    Male      No    0.000000  Not Graduate            No
# 11  LP001082    Male     Yes    1.000000      Graduate           NaN
# 12  LP001083    Male      No    3.000000      Graduate            No
# ...

# %%
# Assuming 'df' is your cleaned DataFrame
df.to_csv(r'C:\Users\tebik\OneDrive\Desktop\DataPy\Datasets\loan-cleaned.csv', index=False)

print("Cleaned data saved as loan-cleaned.csv")
# Out:
# Cleaned data saved as loan-cleaned.csv

# %%
#now all numerical data is cleaned and ready for further analysis

# %%
# Fill missing values in the specified categorical columns with the most frequent value (mode)

categorical_columns = ['Gender', 'Self_Employed', 'Credit_History', 'Loan_Status']

for col in categorical_columns:
    most_frequent_value = df[col].mode()[0]
    df[col] = df[col].fillna(most_frequent_value)  # Reassign the filled column to df[col]

# Print the updated DataFrame
print(df)
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes         0.0      Graduate            No
# 1    LP001022   Male     Yes         1.0      Graduate            No
# 2    LP001031   Male     Yes         2.0      Graduate            No
# 3    LP001035   Male     Yes         2.0      Graduate            No
# 4    LP001051   Male      No         0.0  Not Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 362  LP002971   Male     Yes         3.0  Not Graduate           Yes
# 363  LP002975   Male     Yes         0.0      Graduate            No
# 364  LP002980   Male      No         0.0      Graduate            No
# 365  LP002986   Male     Yes         0.0      Graduate            No
# 366  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Check if the missing values have been filled
print(df[categorical_columns].isnull().sum())
# Out:
# Gender            0
# Self_Employed     0
# Credit_History    0
# Loan_Status       0
# dtype: int64

# %%
# check for missed and duplicates vlues
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(50)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001015    Male     Yes    0.000000      Graduate            No
# 1   LP001022    Male     Yes    1.000000      Graduate            No
# 2   LP001031    Male     Yes    2.000000      Graduate            No
# 3   LP001035    Male     Yes    2.000000      Graduate            No
# 4   LP001051    Male      No    0.000000  Not Graduate            No
# 5   LP001054    Male     Yes    0.000000  Not Graduate           Yes
# 6   LP001055  Female      No    1.000000  Not Graduate            No
# 7   LP001056    Male     Yes    2.000000  Not Graduate            No
# 8   LP001059    Male     Yes    2.000000      Graduate            No
# 9   LP001067    Male      No    0.000000  Not Graduate            No
# 10  LP001078    Male      No    0.000000  Not Graduate            No
# 11  LP001082    Male     Yes    1.000000      Graduate            No
# 12  LP001083    Male      No    3.000000      Graduate            No
# ...

# %%
##Convert categorical features into numerical values (using label encoding) 
# ===>Gender 
#===>Self_Employed
#===>Credit_History
#====>Loan_Status 
#====>Education and
#====>Property_Area

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
categorical_columns = ['Gender', 'Self_Employed', 'Credit_History', 'Loan_Status', 'Married', 'Education', 'Property_Area']
# Apply label encoding to each specified column
for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col].astype(str))  # Convert to string if NaNs are present

print("Updated DataFrame with Label Encoded Columns:")
print(df[categorical_columns].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 label_encoder = LabelEncoder()
#       2 categorical_columns = ['Gender', 'Self_Employed', 'Credit_History', 'Loan_Status', 'Married', 'Education', 'Property_Area']
#       3 # Apply label encoding to each specified column
#
# NameError: name 'LabelEncoder' is not defined

# %%
df.head(50)
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0   LP001015       1        1    0.000000          0              0
# 1   LP001022       1        1    1.000000          0              0
# 2   LP001031       1        1    2.000000          0              0
# 3   LP001035       1        1    2.000000          0              0
# 4   LP001051       1        0    0.000000          1              0
# 5   LP001054       1        1    0.000000          1              1
# 6   LP001055       0        0    1.000000          1              0
# 7   LP001056       1        1    2.000000          1              0
# 8   LP001059       1        1    2.000000          0              0
# 9   LP001067       1        0    0.000000          1              0
# 10  LP001078       1        0    0.000000          1              0
# 11  LP001082       1        1    1.000000          0              0
# 12  LP001083       1        0    3.000000          0              0
# ...

# %%
#Feature scaling: Apply normalization or standardization on numeric features like ApplicantIncome, CoapplicantIncome, and LoanAmount.

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instance
scaler = StandardScaler()

# Select columns to standardize
columns_to_standardize = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

# Apply standardization
df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

print("Standardized data:")
print(df[columns_to_standardize].head())
# Out:
# Standardized data:
#    ApplicantIncome  CoapplicantIncome  LoanAmount
# 0         0.186461          -0.673335   -0.429368
# 1        -0.352692          -0.029848   -0.166482
# 2         0.039641           0.098849    1.180807
# 3        -0.502774           0.418877   -0.593671
# 4        -0.311909          -0.673335   -0.955139

# %%
# identify depedent and indepedent variables
x = df[["ApplicantIncome", "CoapplicantIncome", "LoanAmount", "Credit_History", "Dependents", "Education", "Property_Area"]]

y = df['Loan_Status']

# %%
x
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  \
# 0           0.186461          -0.673335   -0.429368               1
# 1          -0.352692          -0.029848   -0.166482               1
# 2           0.039641           0.098849    1.180807               1
# 3          -0.502774           0.418877   -0.593671               1
# 4          -0.311909          -0.673335   -0.955139               1
# ..               ...                ...         ...             ...
# 362        -0.162439           0.088982   -0.380077               1
# 363        -0.132056          -0.369180   -0.347216               1
# 364        -0.317211           0.181644   -0.166482               1
# 365         0.039641           0.353241    0.359289               1
# 366         0.896087          -0.673335   -0.626532               1
#
#      Dependents  Education  Property_Area
# 0           0.0          0              2
# 1           1.0          0              2
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 362    1
# 363    1
# 364    1
# 365    1
# 366    1
# Name: Loan_Status, Length: 367, dtype: int32

# %%
#Split the dataset into training and testing sets (e.g., 80% training and 20%
# testing)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)
x_train.shape
# Out:
# (293, 7)

# %%
x_test.shape
# Out:
# (74, 7)

# %%
y_train
# Out:
# 255    0
# 261    1
# 348    1
# 151    1
# 34     1
#       ..
# 227    1
# 145    1
# 198    0
# 258    1
# 35     0
# Name: Loan_Status, Length: 293, dtype: int32

# %%
y_test
# Out:
# 247    1
# 57     1
# 241    0
# 102    1
# 117    0
#       ..
# 314    1
# 73     1
# 332    1
# 224    0
# 52     1
# Name: Loan_Status, Length: 74, dtype: int32

# %%
#creat the modele
from sklearn.linear_model import LogisticRegression
our_model = LogisticRegression()
our_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# to know the score
our_model.score(x_train, y_train)
# Out:
# 1.0

# %%
# let we predict using it

x_predict = x[["ApplicantIncome", "CoapplicantIncome", "LoanAmount", "Credit_History", "Dependents", "Education", "Property_Area"]]

# Transform the prediction data (if scaling was applied during training)
#x_predict_scaled = scaler.transform(x_predict)

# Use the model to predict
#predictions = model.predict(x_predict_scaled[3:5])
#print(predictions)

our_model.predict(x[3:10])
# Out:
# array([1, 1, 1, 1, 0, 1, 1])

# %%
x[3:10]
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History  Dependents  \
# 3        -0.502774           0.418877   -0.593671               1         2.0
# 4        -0.311909          -0.673335   -0.955139               1         0.0
# 5        -0.538459           0.794673    0.260707               1         0.0
# 6        -0.526020          -0.673335   -1.267316               1         1.0
# 7        -0.188540          -0.673335    0.178555               0         2.0
# 8         1.800044          -0.673335    2.363793               1         2.0
# 9        -0.490539           0.356244   -0.215773               1         0.0
#
#    Education  Property_Area
# 3          0              2
# 4          1              2
# 5          1              2
# 6          1              1
# 7          1              0
# 8          0              2
# 9          1              1

# %%
#UsetheLoan_Status column as your target variable.
# Evaluate the model’s performance using metrics like accuracy, precision, recall, and F1-score

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 8: Evaluate the model
y_pred = our_model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[12  0]
#  [ 0 62]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        62
#
#     accuracy                           1.00        74
#    macro avg       1.00      1.00      1.00        74
# weighted avg       1.00      1.00      1.00        74

# %%
 #Oncethemodel is trained and evaluated, improve it by experimenting with different pre-processing techniques or hyperparameters (like regularization

#Preprocessing Techniques:
#Feature Scaling
#Handling Missing Data
#Encoding Categorical Variables
#Hyperparameter Tuning
#Regularization Strength
#Regularization Types
#Model Evaluation

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Apply One-Hot Encoding for categorical columns
categorical_cols = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
numeric_cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Dependents']

# Preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(), categorical_cols)
    ]
)

# Combine preprocessing with Logistic Regression
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('logreg', LogisticRegression())
])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
param_grid = {
    'max_depth': [5, 10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
}

# Initialize GridSearchCV with DecisionTreeClassifier
grid_search_dt = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid, cv=5)

# Fit the grid search to the training data
grid_search_dt.fit(x_train, y_train)

# Best hyperparameters
print("Best parameters:", grid_search_dt.best_params_)
# Out:
# Best parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
#Brief conclusions about the model's performance and potential improvements
#Model Performance Analysis

#=>Accuracy:

#===>The model achieved 100% accuracy, meaning all predictions were correct on the test set. While this seems excellent, it’s important to be cautious as it might indicate overfitting, especially if the dataset is small or the test set was not adequately separated.
#=>Confusion Matrix:

#===> True Positives (TP): 62 cases (correctly predicted class 1).
#===> True Negatives (TN): 12 cases (correctly predicted class 0).
#===> False Positives (FP) and False Negatives (FN): None, indicating no misclassifications.

#=>Classification Report:

#===> Precision: For both classes, the model predicted perfectly without any false positives.
#===> Recall: For both classes, the model captured all relevant instances without any false negatives.
#===> F1-Score: Perfect score of 1.00 for both classes due to the absence of errors.
